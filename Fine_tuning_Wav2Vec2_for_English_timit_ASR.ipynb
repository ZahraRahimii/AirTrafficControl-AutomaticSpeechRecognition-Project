# %% [markdown]
# # **Fine-tuning Wav2Vec2 for English ASR with 🤗 Transformers**

# %% [markdown]
# Wav2Vec2 is a pretrained model for Automatic Speech Recognition (ASR) and was released in [September 2020](https://ai.facebook.com/blog/wav2vec-20-learning-the-structure-of-speech-from-raw-audio/) by Alexei Baevski, Michael Auli, and Alex Conneau.
#
# Using a novel contrastive pretraining objective, Wav2Vec2 learns powerful speech representations from more than 50.000 hours of unlabeled speech. Similar, to [BERT's masked language modeling](http://jalammar.github.io/illustrated-bert/), the model learns contextualized speech representations by randomly masking feature vectors before passing them to a transformer network.
#
# ![wav2vec2_structure](https://raw.githubusercontent.com/patrickvonplaten/scientific_images/master/wav2vec2.png)
#
# For the first time, it has been shown that pretraining, followed by fine-tuning on very little labeled speech data achieves competitive results to state-of-the-art ASR systems. Using as little as 10 minutes of labeled data, Wav2Vec2 yields a word error rate (WER) of less than 5% on the clean test set of [LibriSpeech](https://huggingface.co/datasets/librispeech_asr) - *cf.* with Table 9 of the [paper](https://arxiv.org/pdf/2006.11477.pdf).

# %% [markdown]
# In this notebook, we will give an in-detail explanation of how Wav2Vec2's pretrained checkpoints can be fine-tuned on any English ASR dataset. Note that in this notebook, we will fine-tune Wav2Vec2 without making use of a language model. It is much simpler to use Wav2Vec2 without a language model as an end-to-end ASR system and it has been shown that a standalone Wav2Vec2 acoustic model achieves impressive results. For demonstration purposes, we fine-tune the "base"-sized [pretrained checkpoint](https://huggingface.co/facebook/wav2vec2-base) on the rather small [Timit](https://huggingface.co/datasets/timit_asr) dataset that contains just 5h of training data.

# %% [markdown]
# Wav2Vec2 is fine-tuned using Connectionist Temporal Classification (CTC), which is an algorithm that is used to train neural networks for sequence-to-sequence problems and mainly in Automatic Speech Recognition and handwriting recognition.
#
# I highly recommend reading the blog post [Sequence Modeling with CTC (2017)](https://distill.pub/2017/ctc/) very well-written blog post by Awni Hannun.

# %% [markdown]
# First, let's try to get a good GPU in our colab! With Google Colab's free version it's sadly becoming much harder to get access to a good GPU. With Google Colab Pro, one has a much easier time getting access to a V100 or P100 GPU however.

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Oct 21 09:00:55 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P8     9W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# Before we start, let's install both `datasets` and `transformers` from master. Also, we need the `librosa` package to load audio files and the `jiwer` to evaluate our fine-tuned model using the [word error rate (WER)](https://huggingface.co/metrics/wer) metric ${}^1$.

# %%
# %%capture
# !pip install datasets==1.18.3
# !pip install transformers==4.17.0
# !pip install jiwer
# !pip install --upgrade certifi

# %% [markdown]
# Next we strongly suggest to upload your training checkpoints directly to the [🤗 Hub](https://huggingface.co/) while training. The [🤗 Hub](https://huggingface.co/) has integrated version control so you can be sure that no model checkpoint is getting lost during training.
#
# To do so you have to store your authentication token from the Hugging Face website (sign up [here](https://huggingface.co/join) if you haven't already!)

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cd /content

# %%
# !mkdir /content/sample_data/timit_data

# %%
# !wget -P /content/sample_data/timit_data https://data.deepai.org/timit.zip --no-check-certificate
# Out:
# --2022-10-21 09:42:01--  https://data.deepai.org/timit.zip
# Resolving data.deepai.org (data.deepai.org)... 5.9.140.253
# Connecting to data.deepai.org (data.deepai.org)|5.9.140.253|:443... connected.
# WARNING: cannot verify data.deepai.org's certificate, issued by ‘CN=R3,O=Let's Encrypt,C=US’:
#   Issued certificate has expired.
# HTTP request sent, awaiting response... 200 OK
# Length: 869007403 (829M) [application/x-zip-compressed]
# Saving to: ‘/content/sample_data/timit_data/timit.zip’
#
# timit.zip           100%[===================>] 828.75M  15.0MB/s    in 56s
#
# 2022-10-21 09:42:58 (14.7 MB/s) - ‘/content/sample_data/timit_data/timit.zip’ saved [869007403/869007403]

# %%
# !unzip /content/sample_data/timit_data/timit.zip -d  /content/sample_data/timit_data/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1060.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1060.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1060.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1060.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1060.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1690.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1690.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1690.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1690.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI1690.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI2320.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI2320.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI2320.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI2320.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SI2320.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX160.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX160.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX160.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX160.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX160.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX250.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX250.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX250.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX250.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX250.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX340.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX340.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX340.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX340.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX340.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX430.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX430.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX430.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX430.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX430.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX70.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX70.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX70.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX70.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR6/MTXS0/SX70.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1058.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1058.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1058.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1058.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1058.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1688.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1688.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1688.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1688.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI1688.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI2318.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI2318.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI2318.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI2318.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SI2318.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX158.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX158.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX158.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX158.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX158.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX248.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX248.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX248.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX248.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX248.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX338.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX338.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX338.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX338.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX338.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX428.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX428.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX428.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX428.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX428.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX68.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX68.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX68.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX68.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FBLV0/SX68.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI1607.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI1607.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI1607.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI1607.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI1607.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI2237.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI2237.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI2237.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI2237.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI2237.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI977.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI977.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI977.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI977.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SI977.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX167.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX167.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX167.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX167.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX167.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX257.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX257.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX257.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX257.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX257.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX347.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX347.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX347.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX347.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX347.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX437.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX437.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX437.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX437.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX437.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX77.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX77.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX77.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX77.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCJS0/SX77.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI1913.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI1913.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI1913.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI1913.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI1913.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI2053.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI2053.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI2053.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI2053.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI2053.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI793.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI793.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI793.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI793.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SI793.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX163.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX163.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX163.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX163.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX163.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX253.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX253.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX253.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX253.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX253.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX343.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX343.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX343.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX343.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX343.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX433.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX433.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX433.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX433.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX433.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX73.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX73.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX73.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX73.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FCRZ0/SX73.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1047.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1047.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1047.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1047.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1047.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1677.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1677.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1677.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1677.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI1677.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI2307.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI2307.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI2307.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI2307.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SI2307.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX147.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX147.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX147.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX147.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX147.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX237.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX237.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX237.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX237.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX237.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX327.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX327.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX327.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX327.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX327.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX417.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX417.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX417.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX417.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX417.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX57.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX57.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX57.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX57.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJEN0/SX57.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1022.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1022.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1022.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1022.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1022.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1652.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1652.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1652.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1652.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI1652.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI2282.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI2282.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI2282.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI2282.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SI2282.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX122.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX122.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX122.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX122.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX122.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX212.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX212.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX212.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX212.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX212.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX302.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX302.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX302.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX302.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX302.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX32.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX32.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX32.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX32.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX32.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX392.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX392.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX392.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX392.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJHK0/SX392.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI1432.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI1432.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI1432.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI1432.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI1432.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI2062.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI2062.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI2062.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI2062.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI2062.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI802.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI802.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI802.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI802.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SI802.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX172.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX172.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX172.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX172.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX172.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX262.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX262.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX262.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX262.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX262.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX352.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX352.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX352.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX352.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX352.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX442.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX442.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX442.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX442.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX442.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX82.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX82.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX82.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX82.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJRP1/SX82.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1052.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1052.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1052.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1052.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1052.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1682.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1682.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1682.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1682.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI1682.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI2312.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI2312.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI2312.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI2312.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SI2312.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX152.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX152.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX152.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX152.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX152.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX242.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX242.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX242.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX242.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX242.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX332.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX332.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX332.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX332.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX332.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX422.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX422.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX422.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX422.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX422.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX62.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX62.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX62.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX62.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FJSK0/SX62.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1141.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1141.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1141.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1141.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1141.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1771.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1771.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1771.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1771.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI1771.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI2221.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI2221.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI2221.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI2221.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SI2221.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX151.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX151.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX151.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX151.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX151.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX241.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX241.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX241.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX241.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX241.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX331.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX331.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX331.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX331.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX331.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX421.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX421.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX421.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX421.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX421.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX61.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX61.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX61.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX61.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKDE0/SX61.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1117.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1117.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1117.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1117.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1117.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1747.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1747.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1747.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1747.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI1747.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI487.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI487.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI487.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI487.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SI487.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX161.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX161.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX161.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX161.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX161.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX217.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX217.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX217.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX217.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX217.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX366.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX366.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX366.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX366.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX366.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX37.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX37.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX37.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX37.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX37.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX397.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX397.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX397.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX397.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FKSR0/SX397.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1051.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1051.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1051.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1051.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1051.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1681.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1681.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1681.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1681.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI1681.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI2311.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI2311.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI2311.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI2311.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SI2311.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX151.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX151.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX151.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX151.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX151.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX241.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX241.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX241.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX241.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX241.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX331.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX331.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX331.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX331.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX331.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX421.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX421.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX421.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX421.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX421.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX61.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX61.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX61.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX61.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLEH0/SX61.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1137.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1137.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1137.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1137.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1137.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1767.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1767.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1767.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1767.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI1767.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI507.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI507.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI507.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI507.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SI507.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX147.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX147.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX147.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX147.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX147.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX237.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX237.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX237.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX237.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX237.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX277.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX277.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX277.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX277.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX277.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX417.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX417.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX417.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX417.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX417.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX57.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX57.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX57.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX57.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FLET0/SX57.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SI1509.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR7/FMAH1/SI1509.TXT
# ...
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MMWS0/SX78.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MMWS0/SX78.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1044.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1044.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1044.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1044.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1044.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1595.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1595.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1595.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1595.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI1595.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI965.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI965.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI965.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI965.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SI965.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX155.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX155.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX155.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX155.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX155.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX245.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX245.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX245.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX245.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX245.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX335.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX335.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX335.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX335.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX335.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX425.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX425.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX425.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX425.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX425.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX65.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX65.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX65.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX65.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRDM0/SX65.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI1468.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI1468.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI1468.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI1468.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI1468.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI2140.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI2140.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI2140.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI2140.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI2140.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI843.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI843.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI843.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI843.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SI843.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX123.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX123.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX123.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX123.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX123.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX213.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX213.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX213.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX213.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX213.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX303.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX303.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX303.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX303.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX303.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX33.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX33.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX33.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX33.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX33.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX393.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX393.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX393.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX393.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRLK0/SX393.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI1334.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI1334.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI1334.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI1334.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI1334.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI704.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI704.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI704.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI704.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI704.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI952.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI952.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI952.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI952.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SI952.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX164.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX164.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX164.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX164.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX164.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX254.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX254.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX254.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX254.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX254.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX344.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX344.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX344.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX344.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX344.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX434.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX434.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX434.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX434.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX434.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX74.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX74.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX74.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX74.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MRRE0/SX74.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA1.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA1.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA1.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA1.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA1.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA2.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA2.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA2.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA2.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SA2.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI1972.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI1972.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI1972.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI1972.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI1972.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI2265.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI2265.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI2265.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI2265.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI2265.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI712.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI712.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI712.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI712.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SI712.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX172.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX172.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX172.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX172.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX172.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX262.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX262.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX262.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX262.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX262.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX352.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX352.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX352.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX352.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX352.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX442.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX442.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX442.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX442.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX442.WRD
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX82.PHN
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX82.TXT
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX82.WAV
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX82.WAV.wav
#   inflating: /content/sample_data/timit_data/data/TRAIN/DR8/MTCS0/SX82.WRD
#   inflating: /content/sample_data/timit_data/test_data.csv
#   inflating: /content/sample_data/timit_data/train_data.csv

# %% [markdown]
# Then you need to install Git-LFS to upload your model checkpoints:

# %%
# %%capture
# !apt install git-lfs

# %% [markdown]
# ---
#
# ${}^1$ Timit is usually evaluated using the phoneme error rate (PER), but by far the most common metric in ASR is the word error rate (WER). To keep this notebook as general as possible we decided to evaluate the model using WER.

# %% [markdown]
# ## Prepare Data, Tokenizer, Feature Extractor

# %% [markdown]
# ASR models transcribe speech to text, which means that we both need a feature extractor that processes the speech signal to the model's input format, *e.g.* a feature vector, and a tokenizer that processes the model's output format to text.
#
# In 🤗 Transformers, the Wav2Vec2 model is thus accompanied by both a tokenizer, called [Wav2Vec2CTCTokenizer](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2ctctokenizer), and a feature extractor, called [Wav2Vec2FeatureExtractor](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#wav2vec2featureextractor).
#
# Let's start by creating the tokenizer responsible for decoding the model's predictions.

# %% [markdown]
# ### Create Wav2Vec2CTCTokenizer

# %% [markdown]
# The [pretrained Wav2Vec2 checkpoint]( ) maps the speech signal to a sequence of context representations as illustrated in the figure above. A fine-tuned Wav2Vec2 checkpoint needs to map this sequence of context representations to its corresponding transcription so that a linear layer has to be added on top of the transformer block (shown in yellow). This linear layer is used to classifies each context representation to a token class analogous how, *e.g.*, after pretraining a linear layer is added on top of BERT's embeddings for further classification - *cf.* with *"BERT"* section of this [blog post](https://huggingface.co/blog/warm-starting-encoder-decoder).
#
# The output size of this layer corresponds to the number of tokens in the vocabulary, which does **not** depend on Wav2Vec2's pretraining task, but only on the labeled dataset used for fine-tuning. So in the first step, we will take a look at Timit and define a vocabulary based on the dataset's transcriptions.

# %% [markdown]
# Let's start by loading the dataset and taking a look at its structure.

# %%
from datasets import load_dataset, load_metric

timit = load_dataset("timit_asr")
# Out:
# Downloading:   0%|          | 0.00/2.40k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/1.06k [00:00<?, ?B/s]
# Downloading and preparing dataset timit_asr/clean (download: 828.75 MiB, generated: 7.90 MiB, post-processed: Unknown size, total: 836.65 MiB) to /root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad...
# ---------------------------------------------------------------------------
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-2-bbc56949b311> in <module>
#       1 from datasets import load_dataset, load_metric
#       2
# ----> 3 timit = load_dataset("timit_asr")
#
# /usr/local/lib/python3.7/dist-packages/datasets/load.py in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, ignore_verifications, keep_in_memory, save_infos, revision, use_auth_token, task, streaming, script_version, **config_kwargs)
#    1705         ignore_verifications=ignore_verifications,
#    1706         try_from_hf_gcs=try_from_hf_gcs,
# -> 1707         use_auth_token=use_auth_token,
#    1708     )
#    1709
#
# /usr/local/lib/python3.7/dist-packages/datasets/builder.py in download_and_prepare(self, download_config, download_mode, ignore_verifications, try_from_hf_gcs, dl_manager, base_path, use_auth_token, **download_and_prepare_kwargs)
#     593                     if not downloaded_from_gcs:
#     594                         self._download_and_prepare(
# --> 595                             dl_manager=dl_manager, verify_infos=verify_infos, **download_and_prepare_kwargs
#     596                         )
#     597                     # Sync info
#
# /usr/local/lib/python3.7/dist-packages/datasets/builder.py in _download_and_prepare(self, dl_manager, verify_infos, **prepare_split_kwargs)
#     659         split_dict = SplitDict(dataset_name=self.name)
#     660         split_generators_kwargs = self._make_split_generators_kwargs(prepare_split_kwargs)
# --> 661         split_generators = self._split_generators(dl_manager, **split_generators_kwargs)
#     662
#     663         # Checksums verification
#
# ~/.cache/huggingface/modules/datasets_modules/datasets/timit_asr/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad/timit_asr.py in _split_generators(self, dl_manager)
#     107
#     108     def _split_generators(self, dl_manager):
# --> 109         archive_path = dl_manager.download_and_extract(_URL)
#     110
#     111         train_csv_path = os.path.join(archive_path, "train_data.csv")
#
# /usr/local/lib/python3.7/dist-packages/datasets/utils/download_manager.py in download_and_extract(self, url_or_urls)
#     305             extracted_path(s): `str`, extracted paths of given URL(s).
#     306         """
# --> 307         return self.extract(self.download(url_or_urls))
#     308
#     309     def get_recorded_sizes_checksums(self):
#
# /usr/local/lib/python3.7/dist-packages/datasets/utils/download_manager.py in download(self, url_or_urls)
#     194         start_time = datetime.now()
#     195         downloaded_path_or_paths = map_nested(
# --> 196             download_func, url_or_urls, map_tuple=True, num_proc=download_config.num_proc, disable_tqdm=False
#     197         )
#     198         duration = datetime.now() - start_time
#
# /usr/local/lib/python3.7/dist-packages/datasets/utils/py_utils.py in map_nested(function, data_struct, dict_only, map_list, map_tuple, map_numpy, num_proc, types, disable_tqdm)
#     248     # Singleton
#     249     if not isinstance(data_struct, dict) and not isinstance(data_struct, types):
# --> 250         return function(data_struct)
#     251
#     252     disable_tqdm = (
#
# /usr/local/lib/python3.7/dist-packages/datasets/utils/download_manager.py in _download(self, url_or_filename, download_config)
#     214             # append the relative path to the base_path
#     215             url_or_filename = url_or_path_join(self._base_path, url_or_filename)
# --> 216         return cached_path(url_or_filename, download_config=download_config)
#     217
#     218     def iter_archive(self, path_or_buf: Union[str, io.BufferedReader]):
#
# /usr/local/lib/python3.7/dist-packages/datasets/utils/file_utils.py in cached_path(url_or_filename, download_config, **download_kwargs)
#     307             max_retries=download_config.max_retries,
#     308             use_auth_token=download_config.use_auth_token,
# --> 309             ignore_url_params=download_config.ignore_url_params,
#     310         )
#     311     elif os.path.exists(url_or_filename):
#
# /usr/local/lib/python3.7/dist-packages/datasets/utils/file_utils.py in get_from_cache(url, cache_dir, force_download, proxies, etag_timeout, resume_download, user_agent, local_files_only, use_etag, max_retries, use_auth_token, ignore_url_params)
#     613         _raise_if_offline_mode_is_enabled(f"Tried to reach {url}")
#     614         if head_error is not None:
# --> 615             raise ConnectionError(f"Couldn't reach {url} ({repr(head_error)})")
#     616         elif response is not None:
#     617             raise ConnectionError(f"Couldn't reach {url} (error {response.status_code})")
#
# ConnectionError: Couldn't reach https://data.deepai.org/timit.zip (SSLError(MaxRetryError("HTTPSConnectionPool(host='data.deepai.org', port=443): Max retries exceeded with url: /timit.zip (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: certificate has expired (_ssl.c:1091)')))")))

# %%
timit

# %% [markdown]
# Many ASR datasets only provide the target text, `'text'` for each audio `'audio'` and file `'file'`. Timit actually provides much more information about each audio file, such as the `'phonetic_detail'`, etc., which is why many researchers choose to evaluate their models on phoneme classification instead of speech recognition when working with Timit. However, we want to keep the notebook as general as possible, so that we will only consider the transcribed text for fine-tuning.

# %%
timit = timit.remove_columns(["phonetic_detail", "word_detail", "dialect_region", "id", "sentence_type", "speaker_id"])

# %% [markdown]
# Let's write a short function to display some random samples of the dataset and run it a couple of times to get a feeling for the transcriptions.

# %%
from datasets import ClassLabel
import random
import pandas as pd
from IPython.display import display, HTML

def show_random_elements(dataset, num_examples=10):
    assert num_examples <= len(dataset), "Can't pick more elements than there are in the dataset."
    picks = []
    for _ in range(num_examples):
        pick = random.randint(0, len(dataset)-1)
        while pick in picks:
            pick = random.randint(0, len(dataset)-1)
        picks.append(pick)
    
    df = pd.DataFrame(dataset[picks])
    display(HTML(df.to_html()))

# %%
show_random_elements(timit["train"].remove_columns(["audio", "file"]), num_examples=10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>She had your dark suit in greasy wash water all year.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Biblical scholars argue history.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>She had your dark suit in greasy wash water all year.</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Chip postponed alimony payments until the latest possible date.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Don't ask me to carry an oily rag like that.</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Eat your raisins outdoors on the porch steps.</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>George is paranoid about a future gas shortage.</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>It's hard to tell an original from a forgery.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Would you please confirm government policy regarding waste removal?</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>"Infectious hepatitis!", he shouted heartily.</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Alright! The transcriptions look very clean and the language seems to correspond more to written text than dialogue. This makes sense taking into account that [Timit](https://huggingface.co/datasets/timit_asr) is a read speech corpus.

# %% [markdown]
# We can see that the transcriptions contain some special characters, such as `,.?!;:`. Without a language model, it is much harder to classify speech chunks to such special characters because they don't really correspond to a characteristic sound unit. *E.g.*, the letter `"s"` has a more or less clear sound, whereas the special character `"."` does not.
# Also in order to understand the meaning of a speech signal, it is usually not necessary to include special characters in the transcription.
#
# In addition, we normalize the text to only have lower case letters and append a word separator token at the end.

# %%
import re
chars_to_ignore_regex = '[\,\?\.\!\-\;\:\"]'

def remove_special_characters(batch):
    batch["text"] = re.sub(chars_to_ignore_regex, '', batch["text"]).lower() + " "
    return batch

# %%
timit = timit.map(remove_special_characters)
# Out:
# WARNING:datasets.fingerprint:Parameter 'function'=<function remove_special_characters at 0x7ff794f7f830> of the transform datasets.arrow_dataset.Dataset._map_single couldn't be hashed properly, a random hash was used instead. Make sure your transforms and parameters are serializable with pickle or dill for the dataset fingerprinting and caching to work. If you reuse this transform, the caching mechanism will consider it to be different from the previous calls and recompute everything. This warning is only showed once. Subsequent hashing failures won't be showed.
# 0ex [00:00, ?ex/s]
# 0ex [00:00, ?ex/s]

# %%
show_random_elements(timit["train"].remove_columns(["audio", "file"]))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>she had your dark suit in greasy wash water all year</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>rockandroll music has a great rhythm</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>she had your dark suit in greasy wash water all year</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>they had vermouth sitting in front of a cafe</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>now forget all this other</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>she had your dark suit in greasy wash water all year</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>if a concessionaire runs the cafeteria keep an eye out for quality and price</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>those answers will be straightforward if you think them through carefully first</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>there are many such competently anonymous performances among the earlier poems</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>the season between spring and summer belongs to life in its carefree aspect</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Good! This looks better. We have removed most special characters from transcriptions and normalized them to lower-case only.
#
# In CTC, it is common to classify speech chunks into letters, so we will do the same here.
# Let's extract all distinct letters of the training and test data and build our vocabulary from this set of letters.
#
# We write a mapping function that concatenates all transcriptions into one long transcription and then transforms the string into a set of chars.
# It is important to pass the argument `batched=True` to the `map(...)` function so that the mapping function has access to all transcriptions at once.

# %%
def extract_all_chars(batch):
  all_text = " ".join(batch["text"])
  vocab = list(set(all_text))
  return {"vocab": [vocab], "all_text": [all_text]}

# %%
vocabs = timit.map(extract_all_chars, batched=True, batch_size=-1, keep_in_memory=True, remove_columns=timit.column_names["train"])
# Out:
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]

# %% [markdown]
# Now, we create the union of all distinct letters in the training dataset and test dataset and convert the resulting list into an enumerated dictionary.

# %%
vocab_list = list(set(vocabs["train"]["vocab"][0]) | set(vocabs["test"]["vocab"][0]))

# %%
vocab_dict = {v: k for k, v in enumerate(vocab_list)}
vocab_dict
# Out:
# {'l': 0,
#  'o': 1,
#  'a': 2,
#  'x': 3,
#  'h': 4,
#  'y': 5,
#  'z': 6,
#  'm': 7,
#  'n': 8,
#  'g': 9,
#  'b': 10,
#  't': 11,
#  ' ': 12,
#  'c': 13,
#  's': 14,
#  'd': 15,
#  'k': 16,
#  'q': 17,
#  'r': 18,
#  'j': 19,
#  'w': 20,
#  'i': 21,
#  'e': 22,
#  "'": 23,
#  'p': 24,
#  'v': 25,
#  'u': 26,
#  'f': 27}

# %% [markdown]
# Cool, we see that all letters of the alphabet occur in the dataset (which is not really surprising) and we also extracted the special characters `" "` and `'`. Note that we did not exclude those special characters because:
#
# - The model has to learn to predict when a word finished or else the model prediction would always be a sequence of chars which would make it impossible to separate words from each other.
# - In English, we need to keep the `'` character to differentiate between words, *e.g.*, `"it's"` and `"its"` which have very different meanings.

# %% [markdown]
# To make it clearer that `" "` has its own token class, we give it a more visible character `|`. In addition, we also add an "unknown" token so that the model can later deal with characters not encountered in Timit's training set.
#
# Finally, we also add a padding token that corresponds to CTC's "*blank token*". The "blank token" is a core component of the CTC algorithm. For more information, please take a look at the "Alignment" section [here](https://distill.pub/2017/ctc/).

# %%
vocab_dict["|"] = vocab_dict[" "]
del vocab_dict[" "]

# %%
vocab_dict["[UNK]"] = len(vocab_dict)
vocab_dict["[PAD]"] = len(vocab_dict)
len(vocab_dict)
# Out:
# 30

# %% [markdown]
# Cool, now our vocabulary is complete and consists of 30 tokens, which means that the linear layer that we will add on top of the pretrained Wav2Vec2 checkpoint will have an output dimension of 30.

# %% [markdown]
# Let's now save the vocabulary as a json file.

# %%
import json
with open('vocab.json', 'w') as vocab_file:
    json.dump(vocab_dict, vocab_file)

# %% [markdown]
# In a final step, we use the json file to instantiate an object of the `Wav2Vec2CTCTokenizer` class.

# %%
from transformers import Wav2Vec2CTCTokenizer

tokenizer = Wav2Vec2CTCTokenizer("./vocab.json", unk_token="[UNK]", pad_token="[PAD]", word_delimiter_token="|")

# %% [markdown]
# If one wants to re-use the just created tokenizer with the fine-tuned model of this notebook, it is strongly advised to upload the `tokenizer` to the [🤗 Hub](https://huggingface.co/). Let's call the repo to which we will upload the files
# `"wav2vec2-base-timit-demo-colab"`:

# %%
repo_name = "wav2vec2-base-timit-demo-google-colab"

# %% [markdown]
# and upload the tokenizer to the [🤗 Hub](https://huggingface.co/).

# %%
tokenizer.push_to_hub(repo_name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-e531bb070692> in <module>
# ----> 1 tokenizer.push_to_hub(repo_name)
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in push_to_hub(self, repo_path_or_name, repo_url, use_temp_dir, commit_message, organization, private, use_auth_token, **model_card_kwargs)
#    2904             organization=organization,
#    2905             private=private,
# -> 2906             use_auth_token=use_auth_token,
#    2907         )
#    2908         # Save the files in the cloned repo
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in _create_or_get_repo(cls, repo_path_or_name, repo_url, organization, private, use_auth_token)
#    2976             repo_name = Path(repo_path_or_name).name
#    2977             repo_url = cls._get_repo_url_from_name(
# -> 2978                 repo_name, organization=organization, private=private, use_auth_token=use_auth_token
#    2979             )
#    2980
#
# /usr/local/lib/python3.7/dist-packages/transformers/file_utils.py in _get_repo_url_from_name(repo_name, organization, private, use_auth_token)
#    2938             if token is None:
#    2939                 raise ValueError(
# -> 2940                     "You must login to the Hugging Face hub on this computer by typing `transformers-cli login` and "
#    2941                     "entering your credentials to use `use_auth_token=True`. Alternatively, you can pass your own "
#    2942                     "token as the `use_auth_token` argument."
#
# ValueError: You must login to the Hugging Face hub on this computer by typing `transformers-cli login` and entering your credentials to use `use_auth_token=True`. Alternatively, you can pass your own token as the `use_auth_token` argument.

# %% [markdown]
# Great, you can see the just created repository under `https://huggingface.co/<your-username>/wav2vec2-base-timit-demo-colab`

# %% [markdown]
# ### Create Wav2Vec2 Feature Extractor

# %% [markdown]
# Speech is a continuous signal and to be treated by computers, it first has to be discretized, which is usually called **sampling**. The sampling rate hereby plays an important role in that it defines how many data points of the speech signal are measured per second. Therefore, sampling with a higher sampling rate results in a better approximation of the *real* speech signal but also necessitates more values per second.
#
# A pretrained checkpoint expects its input data to have been sampled more or less from the same distribution as the data it was trained on. The same speech signals sampled at two different rates have a very different distribution, *e.g.*, doubling the sampling rate results in data points being twice as long. Thus,
# before fine-tuning a pretrained checkpoint of an ASR model, it is crucial to verify that the sampling rate of the data that was used to pretrain the model matches the sampling rate of the dataset used to fine-tune the model.
#
# Wav2Vec2 was pretrained on the audio data of [LibriSpeech](https://huggingface.co/datasets/librispeech_asr) and LibriVox which both were sampling with 16kHz. Our fine-tuning dataset, [Timit](hhtps://huggingface.co/datasets/timit_asr), was luckily also sampled with 16kHz. If the fine-tuning dataset would have been sampled with a rate lower or higher than 16kHz, we first would have had to up or downsample the speech signal to match the sampling rate of the data used for pretraining.

# %% [markdown]
# A Wav2Vec2 feature extractor object requires the following parameters to be instantiated:
#
# - `feature_size`: Speech models take a sequence of feature vectors as an input. While the length of this sequence obviously varies, the feature size should not. In the case of Wav2Vec2, the feature size is 1 because the model was trained on the raw speech signal ${}^2$.
# - `sampling_rate`: The sampling rate at which the model is trained on.
# - `padding_value`: For batched inference, shorter inputs need to be padded with a specific value
# - `do_normalize`: Whether the input should be *zero-mean-unit-variance* normalized or not. Usually, speech models perform better when normalizing the input
# - `return_attention_mask`: Whether the model should make use of an `attention_mask` for batched inference. In general, models should **always** make use of the `attention_mask` to mask padded tokens. However, due to a very specific design choice of `Wav2Vec2`'s "base" checkpoint, better results are achieved when using no `attention_mask`. This is **not** recommended for other speech models. For more information, one can take a look at [this](https://github.com/pytorch/fairseq/issues/3227) issue. **Important** If you want to use this notebook to fine-tune [large-lv60](https://huggingface.co/facebook/wav2vec2-large-lv60), this parameter should be set to `True`.

# %%
from transformers import Wav2Vec2FeatureExtractor

feature_extractor = Wav2Vec2FeatureExtractor(feature_size=1, sampling_rate=16000, padding_value=0.0, do_normalize=True, return_attention_mask=False)

# %% [markdown]
# Great, Wav2Vec2's feature extraction pipeline is thereby fully defined!
#
# To make the usage of Wav2Vec2 as user-friendly as possible, the feature extractor and tokenizer are *wrapped* into a single `Wav2Vec2Processor` class so that one only needs a `model` and `processor` object.

# %%
from transformers import Wav2Vec2Processor

processor = Wav2Vec2Processor(feature_extractor=feature_extractor, tokenizer=tokenizer)

# %%
if len(processor.tokenizer.get_vocab()) == len(processor.tokenizer):
    print(len(processor.tokenizer))
# Out:
# 30

# %% [markdown]
# Next, we can prepare the dataset.

# %% [markdown]
# ### Preprocess Data
#
# So far, we have not looked at the actual values of the speech signal but just the transcription. In addition to `'text'`, our datasets include two more column names `'file'` and `'audio'`. `'file'` states the absolute path of the audio file. Let's take a look.

# %%
timit["train"][0]["file"]
# Out:
# '/root/.cache/huggingface/datasets/downloads/extracted/404950a46da14eac65eb4e2a8317b1372fb3971d980d91d5d5b221275b1fd7e0/data/TRAIN/DR4/MMDM0/SI681.WAV'

# %% [markdown]
# `Wav2Vec2` expects the input in the format of a 1-dimensional array of 16 kHz. This means that the audio file has to be loaded and resampled.
#
#  Thankfully, `datasets` does this automatically when calling the column `audio`. Let try it out.

# %%
timit["train"][0]["audio"]
# Out:
# {'path': '/root/.cache/huggingface/datasets/downloads/extracted/404950a46da14eac65eb4e2a8317b1372fb3971d980d91d5d5b221275b1fd7e0/data/TRAIN/DR4/MMDM0/SI681.WAV',
#  'array': array([-2.1362305e-04,  6.1035156e-05,  3.0517578e-05, ...,
#         -3.0517578e-05, -9.1552734e-05, -6.1035156e-05], dtype=float32),
#  'sampling_rate': 16000}

# %% [markdown]
# We can see that the audio file has automatically been loaded. This is thanks to the new [`"Audio"` feature](https://huggingface.co/docs/datasets/package_reference/main_classes.html?highlight=audio#datasets.Audio) introduced in `datasets == 4.13.3`, which loads and resamples audio files on-the-fly upon calling.
#
# The sampling rate is set to 16kHz which is what `Wav2Vec2` expects as an input.

# %% [markdown]
# Great, let's listen to a couple of audio files to better understand the dataset and verify that the audio was correctly loaded.
#
# **Note**: *You can click the following cell a couple of times to listen to different speech samples.*

# %%
import IPython.display as ipd
import numpy as np
import random

rand_int = random.randint(0, len(timit["train"]))

print(timit["train"][rand_int]["text"])
ipd.Audio(data=np.asarray(timit["train"][rand_int]["audio"]["array"]), autoplay=True, rate=16000)
# Out:
# top zinnias rarely have crooked stems
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# It can be heard, that the speakers change along with their speaking rate, accent, etc. Overall, the recordings sound relatively clear though, which is to be expected from a read speech corpus.
#
# Let's do a final check that the data is correctly prepared, by printing the shape of the speech input, its transcription, and the corresponding sampling rate.
#
# **Note**: *You can click the following cell a couple of times to verify multiple samples.*

# %%
rand_int = random.randint(0, len(timit["train"]))

print("Target text:", timit["train"][rand_int]["text"])
print("Input array shape:", np.asarray(timit["train"][rand_int]["audio"]["array"]).shape)
print("Sampling rate:", timit["train"][rand_int]["audio"]["sampling_rate"])
# Out:
# Target text: women didn't use white face powder nowadays he recalled
# Input array shape: (56423,)
# Sampling rate: 16000

# %% [markdown]
# Good! Everything looks fine - the data is a 1-dimensional array, the sampling rate always corresponds to 16kHz, and the target text is normalized.

# %% [markdown]
# Finally, we can process the dataset to the format expected by the model for training. We will make use of the `map(...)` function.
#
# First, we load and resample the audio data, simply by calling `batch["audio"]`.
# Second, we extract the `input_values` from the loaded audio file. In our case, the `Wav2Vec2Processor` only normalizes the data. For other speech models, however, this step can include more complex feature extraction, such as [Log-Mel feature extraction](https://en.wikipedia.org/wiki/Mel-frequency_cepstrum).
# Third, we encode the transcriptions to label ids.
#
# **Note**: This mapping function is a good example of how the `Wav2Vec2Processor` class should be used. In "normal" context, calling `processor(...)` is redirected to `Wav2Vec2FeatureExtractor`'s call method. When wrapping the processor into the `as_target_processor` context, however, the same method is redirected to `Wav2Vec2CTCTokenizer`'s call method.
# For more information please check the [docs](https://huggingface.co/transformers/master/model_doc/wav2vec2.html#transformers.Wav2Vec2Processor.__call__).

# %%
def prepare_dataset(batch):
    audio = batch["audio"]

    # batched output is "un-batched" to ensure mapping is correct
    batch["input_values"] = processor(audio["array"], sampling_rate=audio["sampling_rate"]).input_values[0]
    batch["input_length"] = len(batch["input_values"])
    
    with processor.as_target_processor():
        batch["labels"] = processor(batch["text"]).input_ids
    return batch

# %% [markdown]
# Let's apply the data preparation function to all examples.

# %%
timit = timit.map(prepare_dataset, remove_columns=timit.column_names["train"], num_proc=4)

# %% [markdown]
# **Note**: Currently `datasets` make use of [`torchaudio`](https://pytorch.org/audio/stable/index.html) and [`librosa`](https://librosa.org/doc/latest/index.html) for audio loading and resampling. If you wish to implement your own costumized data loading/sampling, feel free to just make use of the `"path"` column instead and disregard the `"audio"` column.

# %% [markdown]
# Long input sequences require a lot of memory. Since `Wav2Vec2` is based on `self-attention` the memory requirement scales quadratically with the input length for long input sequences (*cf.* with [this](https://www.reddit.com/r/MachineLearning/comments/genjvb/d_why_is_the_maximum_input_sequence_length_of/) reddit post). For this demo, let's filter all sequences that are longer than 4 seconds out of the training dataset.

# %%
max_input_length_in_sec = 4.0
timit["train"] = timit["train"].filter(lambda x: x < max_input_length_in_sec * processor.feature_extractor.sampling_rate, input_columns=["input_length"])
# Out:
#   0%|          | 0/5 [00:00<?, ?ba/s]

# %% [markdown]
# Awesome, now we are ready to start training!

# %% [markdown]
# ## Training & Evaluation
#
# The data is processed so that we are ready to start setting up the training pipeline. We will make use of 🤗's [Trainer](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer) for which we essentially need to do the following:
#
# - Define a data collator. In contrast to most NLP models, Wav2Vec2 has a much larger input length than output length. *E.g.*, a sample of input length 50000 has an output length of no more than 100. Given the large input sizes, it is much more efficient to pad the training batches dynamically meaning that all training samples should only be padded to the longest sample in their batch and not the overall longest sample. Therefore, fine-tuning Wav2Vec2 requires a special padding data collator, which we will define below
#
# - Evaluation metric. During training, the model should be evaluated on the word error rate. We should define a `compute_metrics` function accordingly
#
# - Load a pretrained checkpoint. We need to load a pretrained checkpoint and configure it correctly for training.
#
# - Define the training configuration.
#
# After having fine-tuned the model, we will correctly evaluate it on the test data and verify that it has indeed learned to correctly transcribe speech.

# %% [markdown]
# ### Set-up Trainer
#
# Let's start by defining the data collator. The code for the data collator was copied from [this example](https://github.com/huggingface/transformers/blob/9a06b6b11bdfc42eea08fa91d0c737d1863c99e3/examples/research_projects/wav2vec2/run_asr.py#L81).
#
# Without going into too many details, in contrast to the common data collators, this data collator treats the `input_values` and `labels` differently and thus applies to separate padding functions on them (again making use of Wav2Vec2's context manager). This is necessary because in speech input and output are of different modalities meaning that they should not be treated by the same padding function.
# Analogous to the common data collators, the padding tokens in the labels with `-100` so that those tokens are **not** taken into account when computing the loss.

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
import torch

from dataclasses import dataclass, field
from typing import Any, Dict, List, Optional, Union

@dataclass
class DataCollatorCTCWithPadding:
    """
    Data collator that will dynamically pad the inputs received.
    Args:
        processor (:class:`~transformers.Wav2Vec2Processor`)
            The processor used for proccessing the data.
        padding (:obj:`bool`, :obj:`str` or :class:`~transformers.tokenization_utils_base.PaddingStrategy`, `optional`, defaults to :obj:`True`):
            Select a strategy to pad the returned sequences (according to the model's padding side and padding index)
            among:
            * :obj:`True` or :obj:`'longest'`: Pad to the longest sequence in the batch (or no padding if only a single
              sequence if provided).
            * :obj:`'max_length'`: Pad to a maximum length specified with the argument :obj:`max_length` or to the
              maximum acceptable input length for the model if that argument is not provided.
            * :obj:`False` or :obj:`'do_not_pad'` (default): No padding (i.e., can output a batch with sequences of
              different lengths).
        max_length (:obj:`int`, `optional`):
            Maximum length of the ``input_values`` of the returned list and optionally padding length (see above).
        max_length_labels (:obj:`int`, `optional`):
            Maximum length of the ``labels`` returned list and optionally padding length (see above).
        pad_to_multiple_of (:obj:`int`, `optional`):
            If set will pad the sequence to a multiple of the provided value.
            This is especially useful to enable the use of Tensor Cores on NVIDIA hardware with compute capability >=
            7.5 (Volta).
    """

    processor: Wav2Vec2Processor
    padding: Union[bool, str] = True
    max_length: Optional[int] = None
    max_length_labels: Optional[int] = None
    pad_to_multiple_of: Optional[int] = None
    pad_to_multiple_of_labels: Optional[int] = None

    def __call__(self, features: List[Dict[str, Union[List[int], torch.Tensor]]]) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lenghts and need
        # different padding methods
        input_features = [{"input_values": feature["input_values"]} for feature in features]
        label_features = [{"input_ids": feature["labels"]} for feature in features]

        batch = self.processor.pad(
            input_features,
            padding=self.padding,
            max_length=self.max_length,
            pad_to_multiple_of=self.pad_to_multiple_of,
            return_tensors="pt",
        )
        with self.processor.as_target_processor():
            labels_batch = self.processor.pad(
                label_features,
                padding=self.padding,
                max_length=self.max_length_labels,
                pad_to_multiple_of=self.pad_to_multiple_of_labels,
                return_tensors="pt",
            )

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(labels_batch.attention_mask.ne(1), -100)

        batch["labels"] = labels

        return batch

# %%
data_collator = DataCollatorCTCWithPadding(processor=processor, padding=True)

# %% [markdown]
# Next, the evaluation metric is defined. As mentioned earlier, the
# predominant metric in ASR is the word error rate (WER), hence we will use it in this notebook as well.

# %%
wer_metric = load_metric("wer")
# Out:
# Downloading:   0%|          | 0.00/1.90k [00:00<?, ?B/s]

# %% [markdown]
# The model will return a sequence of logit vectors:
# $\mathbf{y}_1, \ldots, \mathbf{y}_m$ with $\mathbf{y}_1 = f_{\theta}(x_1, \ldots, x_n)[0]$ and $n >> m$.
#
# A logit vector $\mathbf{y}_1$ contains the log-odds for each word in the vocabulary we defined earlier, thus $\text{len}(\mathbf{y}_i) =$ `config.vocab_size`. We are interested in the most likely prediction of the model and thus take the `argmax(...)` of the logits. Also, we transform the encoded labels back to the original string by replacing `-100` with the `pad_token_id` and decoding the ids while making sure that consecutive tokens are **not** grouped to the same token in CTC style ${}^1$.

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)

    # if isinstance(label_str, list):
    #     if isinstance(pred_str, list) and len(pred_str) == len(label_str):
    #         for index in random.sample(range(len(label_str)), 3):
    #             print(f'reference: "{label_str[index]}"')
    #             print(f'predicted: "{pred_str[index]}"')

    #     else:
    #         for index in random.sample(range(len(label_str)), 3):
    #             print(f'reference: "{label_str[index]}"')
    #             print(f'predicted: "{pred_str}"')

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %%
def compute_metrics(pred):
    pred_logits = pred.predictions
    pred_ids = np.argmax(pred_logits, axis=-1)

    pred.label_ids[pred.label_ids == -100] = processor.tokenizer.pad_token_id

    pred_str = processor.batch_decode(pred_ids)
    # we do not want to group tokens when computing the metrics
    label_str = processor.batch_decode(pred.label_ids, group_tokens=False)
    
    if isinstance(label_str, list):
        if isinstance(pred_str, list) and len(pred_str) == len(label_str):
            for index in random.sample(range(len(label_str)), 3):
              # add decoder:
                print(f'reference: "{label_str[index]}"')
                print(f'predicted: "{pred_str[index]}"')

        else:
            for index in random.sample(range(len(label_str)), 3):
                print(f'reference: "{label_str[index]}"')
                print(f'predicted: "{pred_str}"')

    wer = wer_metric.compute(predictions=pred_str, references=label_str)

    return {"wer": wer}

# %% [markdown]
# Now, we can load the pretrained `Wav2Vec2` checkpoint. The tokenizer's `pad_token_id` must be to define the model's `pad_token_id` or in the case of `Wav2Vec2ForCTC` also CTC's *blank token* ${}^2$. To save GPU memory, we enable PyTorch's [gradient checkpointing](https://pytorch.org/docs/stable/checkpoint.html) and also set the loss reduction to "*mean*".

# %%
from transformers import Wav2Vec2ForCTC

model = Wav2Vec2ForCTC.from_pretrained(
    "facebook/wav2vec2-base",
    ctc_loss_reduction="mean", 
    # attention_dropout=0.1,
    # mask_time_prob=0.075,
    pad_token_id=processor.tokenizer.pad_token_id,
)
# Out:
# Downloading:   0%|          | 0.00/1.80k [00:00<?, ?B/s]
# /usr/local/lib/python3.7/dist-packages/transformers/configuration_utils.py:357: UserWarning: Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 Transformers. Using `model.gradient_checkpointing_enable()` instead, or if you are using the `Trainer` API, pass `gradient_checkpointing=True` in your `TrainingArguments`.
#   "Passing `gradient_checkpointing` to a config initialization is deprecated and will be removed in v5 "
# Downloading:   0%|          | 0.00/363M [00:00<?, ?B/s]
# Some weights of the model checkpoint at facebook/wav2vec2-base were not used when initializing Wav2Vec2ForCTC: ['project_q.weight', 'project_hid.bias', 'quantizer.weight_proj.bias', 'quantizer.weight_proj.weight', 'quantizer.codevectors', 'project_q.bias', 'project_hid.weight']
# - This IS expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing Wav2Vec2ForCTC from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of Wav2Vec2ForCTC were not initialized from the model checkpoint at facebook/wav2vec2-base and are newly initialized: ['lm_head.weight', 'lm_head.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
# The first component of Wav2Vec2 consists of a stack of CNN layers that are used to extract acoustically meaningful - but contextually independent - features from the raw speech signal. This part of the model has already been sufficiently trained during pretrainind and as stated in the [paper](https://arxiv.org/abs/2006.11477) does not need to be fine-tuned anymore.
# Thus, we can set the `requires_grad` to `False` for all parameters of the *feature extraction* part.

# %%
model.freeze_feature_encoder()

# %% [markdown]
# In a final step, we define all parameters related to training.
# To give more explanation on some of the parameters:
# - `group_by_length` makes training more efficient by grouping training samples of similar input length into one batch. This can significantly speed up training time by heavily reducing the overall number of useless padding tokens that are passed through the model
# - `learning_rate` and `weight_decay` were heuristically tuned until fine-tuning has become stable. Note that those parameters strongly depend on the Timit dataset and might be suboptimal for other speech datasets.
#
# For more explanations on other parameters, one can take a look at the [docs](https://huggingface.co/transformers/master/main_classes/trainer.html?highlight=trainer#trainingarguments).
#
# During training, a checkpoint will be uploaded asynchronously to the hub every 400 training steps. It allows you to also play around with the demo widget even while your model is still training.
#
# **Note**: If one does not want to upload the model checkpoints to the hub, simply set `push_to_hub=False`.

# %%
from transformers import TrainingArguments

training_args = TrainingArguments(
  output_dir=repo_name,
  group_by_length=True,
  per_device_train_batch_size=8,
  per_device_eval_batch_size=8,
  evaluation_strategy="steps",
  num_train_epochs=30,
  # gradient_accumulation_steps = 3,
  fp16=True,
  gradient_checkpointing=True,
  save_steps=500,
  eval_steps=500,
  logging_steps=500,
  learning_rate=1e-4,
  weight_decay=0.005,
  warmup_steps=500,
  save_total_limit=2,
)

# %% [markdown]
# Now, all instances can be passed to Trainer and we are ready to start training!

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    data_collator=data_collator,
    args=training_args,
    compute_metrics=compute_metrics,
    train_dataset=timit["train"],
    eval_dataset=timit["test"],
    tokenizer=processor.feature_extractor,
)
# Out:
# Using amp half precision backend

# %% [markdown]
# ---
#
# ${}^1$ To allow models to become independent of the speaker rate, in CTC, consecutive tokens that are identical are simply grouped as a single token. However, the encoded labels should not be grouped when decoding since they don't correspond to the predicted tokens of the model, which is why the `group_tokens=False` parameter has to be passed. If we wouldn't pass this parameter a word like `"hello"` would incorrectly be encoded, and decoded as `"helo"`.
#
# ${}^2$ The blank token allows the model to predict a word, such as `"hello"` by forcing it to insert the blank token between the two l's. A CTC-conform prediction of `"hello"` of our model would be `[PAD] [PAD] "h" "e" "e" "l" "l" [PAD] "l" "o" "o" [PAD]`.

# %% [markdown]
# ### Training

# %% [markdown]
# Training will take between 90 and 270 minutes depending on the GPU allocated to this notebook. While the trained model yields satisfying results on *Timit*'s test data, it is by no means an optimally fine-tuned model. The purpose of this notebook is to demonstrate how Wav2Vec2's [base](https://huggingface.co/facebook/wav2vec2-base), [large](https://huggingface.co/facebook/wav2vec2-large), and [large-lv60](https://huggingface.co/facebook/wav2vec2-large-lv60) checkpoints can be fine-tuned on any English dataset.
#
# In case you want to use this google colab to fine-tune your model, you should make sure that your training doesn't stop due to inactivity. A simple hack to prevent this is to paste the following code into the console of this tab (*right mouse click -> inspect -> Console tab and insert code*).

# %% [markdown]
# ```javascript
# function ConnectButton(){
#     console.log("Connect pushed");
#     document.querySelector("#top-toolbar > colab-connect-button").shadowRoot.querySelector("#connect").click()
# }
# setInterval(ConnectButton,60000);
# ```

# %% [markdown]
# Depending on what GPU was allocated to your google colab it might be possible that you are seeing an `"out-of-memory"` error here. In this case, it's probably best to reduce `per_device_train_batch_size` to 16 or even less and eventually make use of [`gradient_accumulation`](https://huggingface.co/transformers/master/main_classes/trainer.html#trainingarguments).

# %%
train_result = trainer.train()

metrics = train_result.metrics
max_train_samples = len(timit["train"])
metrics["train_samples"] = min(max_train_samples, len(timit["test"]))

trainer.save_model()

trainer.log_metrics("train", metrics)
trainer.save_metrics("train", metrics)
trainer.save_state()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-3753e551cb87> in <module>
# ----> 1 train_result = trainer.train()
#       2
#       3 metrics = train_result.metrics
#       4 max_train_samples = len(timit["train"])
#       5 metrics["train_samples"] = min(max_train_samples, len(timit["test"]))
#
# NameError: name 'trainer' is not defined

# %% [markdown]
# The final WER should be around 0.3 which is reasonable given that state-of-the-art phoneme error rates (PER) are just below 0.1 (see [leaderboard](https://paperswithcode.com/sota/speech-recognition-on-timit)) and that WER is usually worse than PER.
#
# You can now upload the result of the training to the Hub, just execute this instruction:

# %%
trainer.push_to_hub()
# Out:
# /content/wav2vec2-base-timit-demo-google-colab is already a clone of https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab. Make sure you pull the latest changes with `repo.git_pull()`.
# Saving model checkpoint to wav2vec2-base-timit-demo-google-colab
# Configuration saved in wav2vec2-base-timit-demo-google-colab/config.json
# Model weights saved in wav2vec2-base-timit-demo-google-colab/pytorch_model.bin
# Feature extractor saved in wav2vec2-base-timit-demo-google-colab/preprocessor_config.json
# Upload file pytorch_model.bin:   0%|          | 3.34k/360M [00:00<?, ?B/s]
# Upload file runs/May10_11-02-51_d58de38fbf77/1652180636.6085317/events.out.tfevents.1652180636.d58de38fbf77.96…
# Upload file training_args.bin: 100%|##########| 2.98k/2.98k [00:00<?, ?B/s]
# Upload file runs/May10_11-02-51_d58de38fbf77/events.out.tfevents.1652180636.d58de38fbf77.96.2:  18%|#7        …
# remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab
#    293755a..629f0ba  main -> main
#
# Dropping the following result as it does not have all the necessary fields:
# {}
# remote: Enforcing permissions...
# remote: Allowed refs: all
# To https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab
#    629f0ba..38b281e  main -> main
# 'https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/commit/629f0ba808bdecd2134e2d91110e86e4d7d7647c'

# %% [markdown]
# You can now share this model with all your friends, family, favorite pets: they can all load it with the identifier "your-username/the-name-you-picked" so for instance:

# %% [markdown]
# ```python
# from transformers import AutoModelForCTC, Wav2Vec2Processor
#
# model = AutoModelForCTC.from_pretrained("patrickvonplaten/wav2vec2-base-timit-demo-google-colab")
# processor = Wav2Vec2Processor.from_pretrained("patrickvonplaten/wav2vec2-base-timit-demo-google-colab")
# ```

# %% [markdown]
# ### Evaluate
#
# In the final part, we run our model on some of the validation data to get a feeling for how well it works.
#
# Let's load the `processor` and `model`.

# %%
processor = Wav2Vec2Processor.from_pretrained("patrickvonplaten/wav2vec2-base-timit-demo-google-colab")
# Out:
# https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/preprocessor_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpk25tuj6v
# Downloading:   0%|          | 0.00/215 [00:00<?, ?B/s]
# storing https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/preprocessor_config.json in cache at /root/.cache/huggingface/transformers/17fa07f6e2f88edf24c71037bed1b7cf0cf9acfef7d3353afb589689627542c1.0e3e6656f99a6f7b9eddd943463eb7f34363640fce9e87b047ebd50d4b112b50
# creating metadata file for /root/.cache/huggingface/transformers/17fa07f6e2f88edf24c71037bed1b7cf0cf9acfef7d3353afb589689627542c1.0e3e6656f99a6f7b9eddd943463eb7f34363640fce9e87b047ebd50d4b112b50
# loading feature extractor configuration file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/preprocessor_config.json from cache at /root/.cache/huggingface/transformers/17fa07f6e2f88edf24c71037bed1b7cf0cf9acfef7d3353afb589689627542c1.0e3e6656f99a6f7b9eddd943463eb7f34363640fce9e87b047ebd50d4b112b50
# Feature extractor Wav2Vec2FeatureExtractor {
#   "do_normalize": true,
#   "feature_extractor_type": "Wav2Vec2FeatureExtractor",
#   "feature_size": 1,
#   "padding_side": "right",
#   "padding_value": 0.0,
#   "return_attention_mask": false,
#   "sampling_rate": 16000
# }
#
# https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpu4y_2zcy
# Downloading:   0%|          | 0.00/217 [00:00<?, ?B/s]
# storing https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/tokenizer_config.json in cache at /root/.cache/huggingface/transformers/7bf2e07c1c7ed7e3d055d87aa6bd33c75e6883d98029ae3744fed6bea9e35095.59710b1a6a5501d31e746b6e464f5c44de3e55a58f80634196025936683a68a9
# creating metadata file for /root/.cache/huggingface/transformers/7bf2e07c1c7ed7e3d055d87aa6bd33c75e6883d98029ae3744fed6bea9e35095.59710b1a6a5501d31e746b6e464f5c44de3e55a58f80634196025936683a68a9
# https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/vocab.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpo512ta8n
# Downloading:   0%|          | 0.00/268 [00:00<?, ?B/s]
# storing https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/vocab.json in cache at /root/.cache/huggingface/transformers/f739813380b0880ba302557f0f990f0f64e8efe81fcc91a4fce08206a91ee215.c44a036121683e19f1a033a1765d4344364cb4633a6cbf5cf51b153f2388abb1
# creating metadata file for /root/.cache/huggingface/transformers/f739813380b0880ba302557f0f990f0f64e8efe81fcc91a4fce08206a91ee215.c44a036121683e19f1a033a1765d4344364cb4633a6cbf5cf51b153f2388abb1
# https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmperbfa9_r
# Downloading:   0%|          | 0.00/85.0 [00:00<?, ?B/s]
# storing https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/special_tokens_map.json in cache at /root/.cache/huggingface/transformers/c239f3738252f8d8e83d9813ea82866aeec476c467a008db86229f4edc6490b0.a21d51735cf8667bcd610f057e88548d5d6a381401f6b4501a8bc6c1a9dc8498
# creating metadata file for /root/.cache/huggingface/transformers/c239f3738252f8d8e83d9813ea82866aeec476c467a008db86229f4edc6490b0.a21d51735cf8667bcd610f057e88548d5d6a381401f6b4501a8bc6c1a9dc8498
# loading file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/vocab.json from cache at /root/.cache/huggingface/transformers/f739813380b0880ba302557f0f990f0f64e8efe81fcc91a4fce08206a91ee215.c44a036121683e19f1a033a1765d4344364cb4633a6cbf5cf51b153f2388abb1
# loading file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/tokenizer_config.json from cache at /root/.cache/huggingface/transformers/7bf2e07c1c7ed7e3d055d87aa6bd33c75e6883d98029ae3744fed6bea9e35095.59710b1a6a5501d31e746b6e464f5c44de3e55a58f80634196025936683a68a9
# loading file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/special_tokens_map.json from cache at /root/.cache/huggingface/transformers/c239f3738252f8d8e83d9813ea82866aeec476c467a008db86229f4edc6490b0.a21d51735cf8667bcd610f057e88548d5d6a381401f6b4501a8bc6c1a9dc8498
# Adding <s> to the vocabulary
# Adding </s> to the vocabulary
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = Wav2Vec2ForCTC.from_pretrained("patrickvonplaten/wav2vec2-base-timit-demo-google-colab").cuda()
# Out:
# https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/config.json not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpjeno03v1
# Downloading:   0%|          | 0.00/2.29k [00:00<?, ?B/s]
# storing https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/config.json in cache at /root/.cache/huggingface/transformers/7606a293c66b1cba6bb9a342dcffe3831dc19a120cfeeb9e57cdf6ffb9630f3f.3202909be16e9c482257d0c4d35b4f4c2558cea585027c729eed803ba4bf0d8e
# creating metadata file for /root/.cache/huggingface/transformers/7606a293c66b1cba6bb9a342dcffe3831dc19a120cfeeb9e57cdf6ffb9630f3f.3202909be16e9c482257d0c4d35b4f4c2558cea585027c729eed803ba4bf0d8e
# loading configuration file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/config.json from cache at /root/.cache/huggingface/transformers/7606a293c66b1cba6bb9a342dcffe3831dc19a120cfeeb9e57cdf6ffb9630f3f.3202909be16e9c482257d0c4d35b4f4c2558cea585027c729eed803ba4bf0d8e
# Model config Wav2Vec2Config {
#   "_name_or_path": "facebook/wav2vec2-base",
#   "activation_dropout": 0.0,
#   "adapter_kernel_size": 3,
#   "adapter_stride": 2,
#   "add_adapter": false,
#   "apply_spec_augment": true,
#   "architectures": [
#     "Wav2Vec2ForCTC"
#   ],
#   "attention_dropout": 0.1,
#   "bos_token_id": 1,
#   "classifier_proj_size": 256,
#   "codevector_dim": 256,
#   "contrastive_logits_temperature": 0.1,
#   "conv_bias": false,
#   "conv_dim": [
#     512,
#     512,
#     512,
#     512,
#     512,
#     512,
#     512
#   ],
#   "conv_kernel": [
#     10,
#     3,
#     3,
#     3,
#     3,
#     2,
#     2
#   ],
#   "conv_stride": [
#     5,
#     2,
#     2,
#     2,
#     2,
#     2,
#     2
#   ],
#   "ctc_loss_reduction": "mean",
#   "ctc_zero_infinity": false,
#   "diversity_loss_weight": 0.1,
#   "do_stable_layer_norm": false,
#   "eos_token_id": 2,
#   "feat_extract_activation": "gelu",
#   "feat_extract_norm": "group",
#   "feat_proj_dropout": 0.1,
#   "feat_quantizer_dropout": 0.0,
#   "final_dropout": 0.0,
#   "freeze_feat_extract_train": true,
#   "hidden_act": "gelu",
#   "hidden_dropout": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "layer_norm_eps": 1e-05,
#   "layerdrop": 0.0,
#   "mask_channel_length": 10,
#   "mask_channel_min_space": 1,
#   "mask_channel_other": 0.0,
#   "mask_channel_prob": 0.0,
#   "mask_channel_selection": "static",
#   "mask_feature_length": 10,
#   "mask_feature_min_masks": 0,
#   "mask_feature_prob": 0.0,
#   "mask_time_length": 10,
#   "mask_time_min_masks": 2,
#   "mask_time_min_space": 1,
#   "mask_time_other": 0.0,
#   "mask_time_prob": 0.05,
#   "mask_time_selection": "static",
#   "model_type": "wav2vec2",
#   "no_mask_channel_overlap": false,
#   "no_mask_time_overlap": false,
#   "num_adapter_layers": 3,
#   "num_attention_heads": 12,
#   "num_codevector_groups": 2,
#   "num_codevectors_per_group": 320,
#   "num_conv_pos_embedding_groups": 16,
#   "num_conv_pos_embeddings": 128,
#   "num_feat_extract_layers": 7,
#   "num_hidden_layers": 12,
#   "num_negatives": 100,
#   "output_hidden_size": 768,
#   "pad_token_id": 29,
#   "proj_codevector_dim": 256,
#   "tdnn_dilation": [
#     1,
#     2,
#     3,
#     1,
#     1
#   ],
#   "tdnn_dim": [
#     512,
#     512,
#     512,
#     512,
#     1500
#   ],
#   "tdnn_kernel": [
#     5,
#     3,
#     3,
#     1,
#     1
#   ],
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "use_weighted_layer_sum": false,
#   "vocab_size": 32,
#   "xvector_output_dim": 512
# }
#
# https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to /root/.cache/huggingface/transformers/tmpzxx834q2
# Downloading:   0%|          | 0.00/360M [00:00<?, ?B/s]
# storing https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/pytorch_model.bin in cache at /root/.cache/huggingface/transformers/666767bce47a87d50dfd1ceac759d5dc9db6eac8d185ae8f9a7dd388687c28c5.20bdf845b9896c1d0a213f03187b544f2a12b23d751b88c7b49a95d00bd946e1
# creating metadata file for /root/.cache/huggingface/transformers/666767bce47a87d50dfd1ceac759d5dc9db6eac8d185ae8f9a7dd388687c28c5.20bdf845b9896c1d0a213f03187b544f2a12b23d751b88c7b49a95d00bd946e1
# loading weights file https://huggingface.co/patrickvonplaten/wav2vec2-base-timit-demo-google-colab/resolve/main/pytorch_model.bin from cache at /root/.cache/huggingface/transformers/666767bce47a87d50dfd1ceac759d5dc9db6eac8d185ae8f9a7dd388687c28c5.20bdf845b9896c1d0a213f03187b544f2a12b23d751b88c7b49a95d00bd946e1
# All model checkpoint weights were used when initializing Wav2Vec2ForCTC.
#
# All the weights of Wav2Vec2ForCTC were initialized from the model checkpoint at patrickvonplaten/wav2vec2-base-timit-demo-google-colab.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use Wav2Vec2ForCTC for predictions without further training.

# %% [markdown]
# Now Evaluate:

# %%
results = {}
metrics = trainer.evaluate()
max_val_samples = len(timit["test"])
metrics["eval_samples"] = min(max_val_samples, len(timit["test"]))

trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# The following columns in the evaluation set  don't have a corresponding argument in `Wav2Vec2ForCTC.forward` and have been ignored: input_length. If input_length are not expected by `Wav2Vec2ForCTC.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 1680
#   Batch size = 8
#     <div>
#
#       <progress value='210' max='210' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [210/210 01:09]
#     </div>
# reference: "gjvsvpv dnvojrddvyroprnvbnswgngr dn"
# predicted: "gjvsv dnvojrdvyropnvbnswgngdnk"
# reference: "jxrvgnhgwhbnkrgrnjkwnbjrhd aargbn npx vgn oan nh dzns on"
# predicted: "jxrgnhgwhbnkrgnjnbjrhnd  argbn npx gn oan nhzns onk"
# reference: "vsnhrwhdrnkrgrnzwgrnyrorgwmbnjxrgrnkwmdan'rnownorranswgnkrds grn"
# predicted: "vsnhrhdnkrgnzwgnyrorgwbjxrgnkwdan'rnownoranswgnkrds gnk"
# ***** eval metrics *****
#   epoch                   =        5.0
#   eval_loss               =     0.6476
#   eval_runtime            = 0:01:11.26
#   eval_samples            =       1680
#   eval_samples_per_second =     23.575
#   eval_steps_per_second   =      2.947
#   eval_wer                =     0.7136

# %% [markdown]
# Now, we will just take the first example of the test set, run it through the model and take the argmax(...) of the logits to retrieve the predicted token ids.

# %%
input_dict = processor(timit["test"]["input_values"][2], return_tensors="pt", padding=True)

logits = model(input_dict.input_values.to("cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)[0]
# Out:
# It is strongly recommended to pass the ``sampling_rate`` argument to this function. Failing to do so can result in silent errors that might be hard to debug.

# %% [markdown]
# We adapted timit quite a bit so that the dataset instance does not contain the original sentence label anymore. Thus, we re-use the original dataset to get the label of the first example.

# %%
timit_test_transcription = load_dataset("timit_asr")
# Out:
# WARNING:datasets.builder:Reusing dataset timit_asr (/root/.cache/huggingface/datasets/timit_asr/clean/2.0.1/b11b576ddcccbcefa7c9f0c4e6c2a43756f3033adffe0fb686aa61043d0450ad)
#   0%|          | 0/2 [00:00<?, ?it/s]

# %% [markdown]
# Finally, we can decode the example.

# %%
print("Prediction:")
print(processor.decode(pred_ids))

print("\nReference:")
print(timit_test_transcription["test"]["text"][2].lower())
# Out:
# Prediction:
# are you looking for employment
#
# Reference:
# are you looking for employment?

# %% [markdown]
# It becomes clear that the predicted transcriptions are acoustically very similar to the target transcriptions, but often contain spelling or grammatical errors. This shouldn't be very surprising though given that we purely rely on Wav2Vec2 without making use of a language model.

# %% [markdown]
# Finally, to better understand how CTC works, it is worth taking a deeper look at the exact output of the model. Let's run the first test sample through the model, take the predicted ids and convert them to their corresponding tokens.

# %%
model.to("cuda")

with torch.no_grad():
  logits = model(torch.tensor(timit["test"][:1]["input_values"], device="cuda")).logits

pred_ids = torch.argmax(logits, dim=-1)

# convert ids to tokens
" ".join(processor.tokenizer.convert_ids_to_tokens(pred_ids[0].tolist()))
# Out:
# '[PAD] [PAD] [PAD] [PAD] [PAD] t t h h e | | | b [PAD] [PAD] [PAD] u u n n g g [PAD] [PAD] l l l l [PAD] o o o | | w w a a s s | | [PAD] [PAD] [PAD] p l l [PAD] e s s s s [PAD] n n t t [PAD] l l l y y | | [PAD] s s s i i t t t [PAD] u u u u u [PAD] [PAD] [PAD] [PAD] a a t t [PAD] e e d d | | [PAD] n n e e a a r | | t t h e e | | s s h h [PAD] [PAD] [PAD] [PAD] o o r r r r | [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD] [PAD]'

# %% [markdown]
# The output should make it a bit clearer how CTC works in practice. The model is to some extent invariant to speaking rate since it has learned to either just repeat the same token in case the speech chunk to be classified still corresponds to the same token. This makes CTC a very powerful algorithm for speech recognition since the speech file's transcription is often very much independent of its length.
#
# I again advise the reader to take a look at [this](https://distill.pub/2017/ctc) very nice blog post to better understand CTC.
